# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # SQL advanced string functions
# © ExploreAI Academy

# %% [markdown]
# In this exercise, we will use the skills we have learned so far to solve complex problems that involve string manipulation and handling. Ensure that you have downloaded the database file, Northwind.db.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will:
# - Understand how to apply  SQL functions for data type conversion, null value handling, and string manipulation to solve complex problems.

# %% [markdown]
# First, let's load our database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///Northwind.db
# Out:
# 'Connected: @Northwind.db'

# %% [markdown]
# Here is a view of all of our tables in the database:
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:70%";/>
# <br>
# <br>
#     <em>Figure 1: Northwind database ERD</em>
# </div>

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Convert data type
#
# Given the `Employees` table, write a SQL query to convert the salary of all employees from integer to string data type.

# %%
# %%sql
#
# select
# 	salary,
#     Cast(Salary AS Varchar) AS New_salary
# from
# 	employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(2954.55, '2954.55'),
#  (2254.49, '2254.49'),
#  (3119.15, '3119.15'),
#  (1861.08, '1861.08'),
#  (1744.21, '1744.21'),
#  (2004.07, '2004.07'),
#  (1991.55, '1991.55'),
#  (2100.5, '2100.5'),
#  (2333.33, '2333.33')]

# %% [markdown]
# ### 2. Trim strings
#
# In the `Orders` table, some of the `ShipName` entries have leading and trailing white spaces. Write a SQL query to trim these white spaces.

# %%
# %%sql
#
# select
# 	OrderId,
#     LTRIM(RTRIM(ShipName))
# from
# 	orders;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(10248, 'Vins et alcools Chevalier'),
#  (10249, 'Toms Spezialitten'),
#  (10250, 'Hanari Carnes'),
#  (10251, 'Victuailles en stock'),
#  (10252, 'Suprmes dlices'),
#  (10253, 'Hanari Carnes'),
#  (10254, 'Chop-suey Chinese'),
#  (10255, 'Richter Supermarkt'),
#  (10256, 'Wellington Importadora'),
#  (10257, 'HILARION-Abastos'),
#  (10258, 'Ernst Handel'),
#  (10259, 'Centro comercial Moctezuma'),
#  (10260, 'Ottilies Kseladen'),
#  (10261, 'Que Delcia'),
#  (10262, 'Rattlesnake Canyon Grocery'),
#  (10263, 'Ernst Handel'),
#  (10264, 'Folk och f HB'),
#  (10265, 'Blondel pre et fils'),
#  (10266, 'Wartian Herkku'),
#  (10267, 'Frankenversand'),
#  (10268, 'GROSELLA-Restaurante'),
#  (10269, 'White Clover Markets'),
#  (10270, 'Wartian Herkku'),
#  (10271, 'Split Rail Beer & Ale'),
#  (10272, 'Rattlesnake Canyon Grocery'),
#  (10273, 'QUICK-Stop'),
#  (10274, 'Vins et alcools Chevalier'),
#  (10275, 'Magazzini Alimentari Riuniti'),
#  (10276, 'Tortuga Restaurante'),
#  (10277, 'Morgenstern Gesundkost'),
#  (10278, 'Berglunds snabbkp'),
#  (10279, 'Lehmanns Marktstand'),
#  (10280, 'Berglunds snabbkp'),
#  (10281, 'Romero y tomillo'),
#  (10282, 'Romero y tomillo'),
#  (10283, 'LILA-Supermercado'),
#  (10284, 'Lehmanns Marktstand'),
#  (10285, 'QUICK-Stop'),
#  (10286, 'QUICK-Stop'),
#  (10287, 'Ricardo Adocicados'),
#  (10288, 'Reggiani Caseifici'),
#  (10289, 'B-s Beverages'),
#  (10290, 'Comrcio Mineiro'),
#  (10291, 'Que Delcia'),
#  (10292, 'Tradiao Hipermercados'),
#  (10293, 'Tortuga Restaurante'),
#  (10294, 'Rattlesnake Canyon Grocery'),
#  (10295, 'Vins et alcools Chevalier'),
#  (10296, 'LILA-Supermercado'),
#  (10297, 'Blondel pre et fils'),
#  (10298, 'Hungry Owl All-Night Grocers'),
#  (10299, 'Ricardo Adocicados'),
#  (10300, 'Magazzini Alimentari Riuniti'),
#  (10301, 'Die Wandernde Kuh'),
#  (10302, 'Suprmes dlices'),
#  (10303, 'Godos Cocina Tpica'),
#  (10304, 'Tortuga Restaurante'),
#  (10305, 'Old World Delicatessen'),
#  (10306, 'Romero y tomillo'),
#  (10307, 'Lonesome Pine Restaurant'),
#  (10308, 'Ana Trujillo Emparedados y helados'),
#  (10309, 'Hungry Owl All-Night Grocers'),
#  (10310, 'The Big Cheese'),
#  (10311, 'Du monde entier'),
#  (10312, 'Die Wandernde Kuh'),
#  (10313, 'QUICK-Stop'),
#  (10314, 'Rattlesnake Canyon Grocery'),
#  (10315, 'Island Trading'),
#  (10316, 'Rattlesnake Canyon Grocery'),
#  (10317, 'Lonesome Pine Restaurant'),
#  (10318, 'Island Trading'),
#  (10319, 'Tortuga Restaurante'),
#  (10320, 'Wartian Herkku'),
#  (10321, 'Island Trading'),
#  (10322, 'Pericles Comidas clsicas'),
#  (10323, 'Kniglich Essen'),
#  (10324, 'Save-a-lot Markets'),
#  (10325, 'Kniglich Essen'),
#  (10326, 'Blido Comidas preparadas'),
#  (10327, 'Folk och f HB'),
#  (10328, 'Furia Bacalhau e Frutos do Mar'),
#  (10329, 'Split Rail Beer & Ale'),
#  (10330, 'LILA-Supermercado'),
#  (10331, 'Bon app-'),
#  (10332, 'Mre Paillarde'),
#  (10333, 'Wartian Herkku'),
#  (10334, 'Victuailles en stock'),
#  (10335, 'Hungry Owl All-Night Grocers'),
#  (10336, 'Princesa Isabel Vinhos'),
#  (10337, 'Frankenversand'),
#  (10338, 'Old World Delicatessen'),
#  (10339, 'Mre Paillarde'),
#  (10340, 'Bon app-'),
#  (10341, 'Simons bistro'),
#  (10342, 'Frankenversand'),
#  (10343, 'Lehmanns Marktstand'),
#  (10344, 'White Clover Markets'),
#  (10345, 'QUICK-Stop'),
#  (10346, 'Rattlesnake Canyon Grocery'),
#  (10347, 'Familia Arquibaldo'),
#  (10348, 'Die Wandernde Kuh'),
#  (10349, 'Split Rail Beer & Ale'),
#  (10350, 'La maison d-Asie'),
#  (10351, 'Ernst Handel'),
#  (10352, 'Furia Bacalhau e Frutos do Mar'),
#  (10353, 'Piccolo und mehr'),
#  (10354, 'Pericles Comidas clsicas'),
#  (10355, 'Around the Horn'),
#  (10356, 'Die Wandernde Kuh'),
#  (10357, 'LILA-Supermercado'),
#  (10358, 'La maison d-Asie'),
#  (10359, 'Seven Seas Imports'),
#  (10360, 'Blondel pre et fils'),
#  (10361, 'QUICK-Stop'),
#  (10362, 'Bon app-'),
#  (10363, 'Drachenblut Delikatessen'),
#  (10364, 'Eastern Connection'),
#  (10365, 'Antonio Moreno Taquera'),
#  (10366, 'Galera del gastronmo'),
#  (10367, 'Vaffeljernet'),
#  (10368, 'Ernst Handel'),
#  (10369, 'Split Rail Beer & Ale'),
#  (10370, 'Chop-suey Chinese'),
#  (10371, 'La maison d-Asie'),
#  (10372, 'Queen Cozinha'),
#  (10373, 'Hungry Owl All-Night Grocers'),
#  (10374, 'Wolski Zajazd'),
#  (10375, 'Hungry Coyote Import Store'),
#  (10376, 'Mre Paillarde'),
#  (10377, 'Seven Seas Imports'),
#  (10378, 'Folk och f HB'),
#  (10379, 'Que Delcia'),
#  (10380, 'Hungry Owl All-Night Grocers'),
#  (10381, 'LILA-Supermercado'),
#  (10382, 'Ernst Handel'),
#  (10383, 'Around the Horn'),
#  (10384, 'Berglunds snabbkp'),
#  (10385, 'Split Rail Beer & Ale'),
#  (10386, 'Familia Arquibaldo'),
#  (10387, 'Sant Gourmet'),
#  (10388, 'Seven Seas Imports'),
#  (10389, 'Bottom-Dollar Markets'),
#  (10390, 'Ernst Handel'),
#  (10391, 'Drachenblut Delikatessen'),
#  (10392, 'Piccolo und mehr'),
#  (10393, 'Save-a-lot Markets'),
#  (10394, 'Hungry Coyote Import Store'),
#  (10395, 'HILARION-Abastos'),
#  (10396, 'Frankenversand'),
#  (10397, 'Princesa Isabel Vinhos'),
#  (10398, 'Save-a-lot Markets'),
#  (10399, 'Vaffeljernet'),
#  (10400, 'Eastern Connection'),
#  (10401, 'Rattlesnake Canyon Grocery'),
#  (10402, 'Ernst Handel'),
#  (10403, 'Ernst Handel'),
#  (10404, 'Magazzini Alimentari Riuniti'),
#  (10405, 'LINO-Delicateses'),
#  (10406, 'Queen Cozinha'),
#  (10407, 'Ottilies Kseladen'),
#  (10408, 'Folies gourmandes'),
#  (10409, 'Ocano Atlntico Ltda.'),
#  (10410, 'Bottom-Dollar Markets'),
#  (10411, 'Bottom-Dollar Markets'),
#  (10412, 'Wartian Herkku'),
#  (10413, 'La maison d-Asie'),
#  (10414, 'Familia Arquibaldo'),
#  (10415, 'Hungry Coyote Import Store'),
#  (10416, 'Wartian Herkku'),
#  (10417, 'Simons bistro'),
#  (10418, 'QUICK-Stop'),
#  (10419, 'Richter Supermarkt'),
#  (10420, 'Wellington Importadora'),
#  (10421, 'Que Delcia'),
#  (10422, 'Franchi S.p.A.'),
#  (10423, 'Gourmet Lanchonetes'),
#  (10424, 'Mre Paillarde'),
#  (10425, 'La maison d-Asie'),
#  (10426, 'Galera del gastronmo'),
#  (10427, 'Piccolo und mehr'),
#  (10428, 'Reggiani Caseifici'),
#  (10429, 'Hungry Owl All-Night Grocers'),
#  (10430, 'Ernst Handel'),
#  (10431, 'Bottom-Dollar Markets'),
#  (10432, 'Split Rail Beer & Ale'),
#  (10433, 'Princesa Isabel Vinhos'),
#  (10434, 'Folk och f HB'),
#  (10435, 'Consolidated Holdings'),
#  (10436, 'Blondel pre et fils'),
#  (10437, 'Wartian Herkku'),
#  (10438, 'Toms Spezialitten'),
#  (10439, 'Mre Paillarde'),
#  (10440, 'Save-a-lot Markets'),
#  (10441, 'Old World Delicatessen'),
#  (10442, 'Ernst Handel'),
#  (10443, 'Reggiani Caseifici'),
#  (10444, 'Berglunds snabbkp'),
#  (10445, 'Berglunds snabbkp'),
#  (10446, 'Toms Spezialitten'),
#  (10447, 'Ricardo Adocicados'),
#  (10448, 'Rancho grande'),
#  (10449, 'Blondel pre et fils'),
#  (10450, 'Victuailles en stock'),
#  (10451, 'QUICK-Stop'),
#  (10452, 'Save-a-lot Markets'),
#  (10453, 'Around the Horn'),
#  (10454, 'La maison d-Asie'),
#  (10455, 'Wartian Herkku'),
#  (10456, 'Kniglich Essen'),
#  (10457, 'Kniglich Essen'),
#  (10458, 'Suprmes dlices'),
#  (10459, 'Victuailles en stock'),
#  (10460, 'Folk och f HB'),
#  (10461, 'LILA-Supermercado'),
#  (10462, 'Consolidated Holdings'),
#  (10463, 'Suprmes dlices'),
#  (10464, 'Furia Bacalhau e Frutos do Mar'),
#  (10465, 'Vaffeljernet'),
#  (10466, 'Comrcio Mineiro'),
#  (10467, 'Magazzini Alimentari Riuniti'),
#  (10468, 'Kniglich Essen'),
#  (10469, 'White Clover Markets'),
#  (10470, 'Bon app-'),
#  (10471, 'B-s Beverages'),
#  (10472, 'Seven Seas Imports'),
#  (10473, 'Island Trading'),
#  (10474, 'Pericles Comidas clsicas'),
#  (10475, 'Suprmes dlices'),
#  (10476, 'HILARION-Abastos'),
#  (10477, 'Princesa Isabel Vinhos'),
#  (10478, 'Victuailles en stock'),
#  (10479, 'Rattlesnake Canyon Grocery'),
#  (10480, 'Folies gourmandes'),
#  (10481, 'Ricardo Adocicados'),
#  (10482, 'Lazy K Kountry Store'),
#  (10483, 'White Clover Markets'),
#  (10484, 'B-s Beverages'),
#  (10485, 'LINO-Delicateses'),
#  (10486, 'HILARION-Abastos'),
#  (10487, 'Queen Cozinha'),
#  (10488, 'Frankenversand'),
#  (10489, 'Piccolo und mehr'),
#  (10490, 'HILARION-Abastos'),
#  (10491, 'Furia Bacalhau e Frutos do Mar'),
#  (10492, 'Bottom-Dollar Markets'),
#  (10493, 'La maison d-Asie'),
#  (10494, 'Comrcio Mineiro'),
#  (10495, 'Laughing Bacchus Wine Cellars'),
#  (10496, 'Tradiao Hipermercados'),
#  (10497, 'Lehmanns Marktstand'),
#  (10498, 'HILARION-Abastos'),
#  (10499, 'LILA-Supermercado'),
#  (10500, 'La maison d-Asie'),
#  (10501, 'Blauer See Delikatessen'),
#  (10502, 'Pericles Comidas clsicas'),
#  (10503, 'Hungry Owl All-Night Grocers'),
#  (10504, 'White Clover Markets'),
#  (10505, 'Mre Paillarde'),
#  (10506, 'Kniglich Essen'),
#  (10507, 'Antonio Moreno Taquera'),
#  (10508, 'Ottilies Kseladen'),
#  (10509, 'Blauer See Delikatessen'),
#  (10510, 'Save-a-lot Markets'),
#  (10511, 'Bon app-'),
#  (10512, 'Familia Arquibaldo'),
#  (10513, 'Die Wandernde Kuh'),
#  (10514, 'Ernst Handel'),
#  (10515, 'QUICK-Stop'),
#  (10516, 'Hungry Owl All-Night Grocers'),
#  (10517, 'North/South'),
#  (10518, 'Tortuga Restaurante'),
#  (10519, 'Chop-suey Chinese'),
#  (10520, 'Sant Gourmet'),
#  (10521, 'Cactus Comidas para llevar'),
#  (10522, 'Lehmanns Marktstand'),
#  (10523, 'Seven Seas Imports'),
#  (10524, 'Berglunds snabbkp'),
#  (10525, 'Bon app-'),
#  (10526, 'Wartian Herkku'),
#  (10527, 'QUICK-Stop'),
#  (10528, 'Great Lakes Food Market'),
#  (10529, 'Maison Dewey'),
#  (10530, 'Piccolo und mehr'),
#  (10531, 'Ocano Atlntico Ltda.'),
#  (10532, 'Eastern Connection'),
#  (10533, 'Folk och f HB'),
#  (10534, 'Lehmanns Marktstand'),
#  (10535, 'Antonio Moreno Taquera'),
#  (10536, 'Lehmanns Marktstand'),
#  (10537, 'Richter Supermarkt'),
#  (10538, 'B-s Beverages'),
#  (10539, 'B-s Beverages'),
#  (10540, 'QUICK-Stop'),
#  (10541, 'Hanari Carnes'),
#  (10542, 'Kniglich Essen'),
#  (10543, 'LILA-Supermercado'),
#  (10544, 'Lonesome Pine Restaurant'),
#  (10545, 'Lazy K Kountry Store'),
#  (10546, 'Victuailles en stock'),
#  (10547, 'Seven Seas Imports'),
#  (10548, 'Toms Spezialitten'),
#  (10549, 'QUICK-Stop'),
#  (10550, 'Godos Cocina Tpica'),
#  (10551, 'Furia Bacalhau e Frutos do Mar'),
#  (10552, 'HILARION-Abastos'),
#  (10553, 'Wartian Herkku'),
#  (10554, 'Ottilies Kseladen'),
#  (10555, 'Save-a-lot Markets'),
#  (10556, 'Simons bistro'),
#  (10557, 'Lehmanns Marktstand'),
#  (10558, 'Around the Horn'),
#  (10559, 'Blondel pre et fils'),
#  (10560, 'Frankenversand'),
#  (10561, 'Folk och f HB'),
#  (10562, 'Reggiani Caseifici'),
#  (10563, 'Ricardo Adocicados'),
#  (10564, 'Rattlesnake Canyon Grocery'),
#  (10565, 'Mre Paillarde'),
#  (10566, 'Blondel pre et fils'),
#  (10567, 'Hungry Owl All-Night Grocers'),
#  (10568, 'Galera del gastronmo'),
#  (10569, 'Rattlesnake Canyon Grocery'),
#  (10570, 'Mre Paillarde'),
#  (10571, 'Ernst Handel'),
#  (10572, 'Berglunds snabbkp'),
#  (10573, 'Antonio Moreno Taquera'),
#  (10574, 'Trail-s Head Gourmet Provisioners'),
#  (10575, 'Morgenstern Gesundkost'),
#  (10576, 'Tortuga Restaurante'),
#  (10577, 'Trail-s Head Gourmet Provisioners'),
#  (10578, 'B-s Beverages'),
#  (10579, 'Let-s Stop N Shop'),
#  (10580, 'Ottilies Kseladen'),
#  (10581, 'Familia Arquibaldo'),
#  (10582, 'Blauer See Delikatessen'),
#  (10583, 'Wartian Herkku'),
#  (10584, 'Blondel pre et fils'),
#  (10585, 'Wellington Importadora'),
#  (10586, 'Reggiani Caseifici'),
#  (10587, 'Que Delcia'),
#  (10588, 'QUICK-Stop'),
#  (10589, 'Great Lakes Food Market'),
#  (10590, 'Mre Paillarde'),
#  (10591, 'Vaffeljernet'),
#  (10592, 'Lehmanns Marktstand'),
#  (10593, 'Lehmanns Marktstand'),
#  (10594, 'Old World Delicatessen'),
#  (10595, 'Ernst Handel'),
#  (10596, 'White Clover Markets'),
#  (10597, 'Piccolo und mehr'),
#  (10598, 'Rattlesnake Canyon Grocery'),
#  (10599, 'B-s Beverages'),
#  (10600, 'Hungry Coyote Import Store'),
#  (10601, 'HILARION-Abastos'),
#  (10602, 'Vaffeljernet'),
#  (10603, 'Save-a-lot Markets'),
#  (10604, 'Furia Bacalhau e Frutos do Mar'),
#  (10605, 'Mre Paillarde'),
#  (10606, 'Tradiao Hipermercados'),
#  (10607, 'Save-a-lot Markets'),
#  (10608, 'Toms Spezialitten'),
#  (10609, 'Du monde entier'),
#  (10610, 'La maison d-Asie'),
#  (10611, 'Wolski Zajazd'),
#  (10612, 'Save-a-lot Markets'),
#  (10613, 'HILARION-Abastos'),
#  (10614, 'Blauer See Delikatessen'),
#  (10615, 'Wilman Kala'),
#  (10616, 'Great Lakes Food Market'),
#  (10617, 'Great Lakes Food Market'),
#  (10618, 'Mre Paillarde'),
#  (10619, 'Mre Paillarde'),
#  (10620, 'Laughing Bacchus Wine Cellars'),
#  (10621, 'Island Trading'),
#  (10622, 'Ricardo Adocicados'),
#  (10623, 'Frankenversand'),
#  (10624, 'The Cracker Box'),
#  (10625, 'Ana Trujillo Emparedados y helados'),
#  (10626, 'Berglunds snabbkp'),
#  (10627, 'Save-a-lot Markets'),
#  (10628, 'Blondel pre et fils'),
#  (10629, 'Godos Cocina Tpica'),
#  (10630, 'Kniglich Essen'),
#  (10631, 'La maison d-Asie'),
#  (10632, 'Die Wandernde Kuh'),
#  (10633, 'Ernst Handel'),
#  (10634, 'Folies gourmandes'),
#  (10635, 'Magazzini Alimentari Riuniti'),
#  (10636, 'Wartian Herkku'),
#  (10637, 'Queen Cozinha'),
#  (10638, 'LINO-Delicateses'),
#  (10639, 'Sant Gourmet'),
#  (10640, 'Die Wandernde Kuh'),
#  (10641, 'HILARION-Abastos'),
#  (10642, 'Simons bistro'),
#  (10643, 'Alfreds Futterkiste'),
#  (10644, 'Wellington Importadora'),
#  (10645, 'Hanari Carnes'),
#  (10646, 'Hungry Owl All-Night Grocers'),
#  (10647, 'Que Delcia'),
#  (10648, 'Ricardo Adocicados'),
#  (10649, 'Maison Dewey'),
#  (10650, 'Familia Arquibaldo'),
#  (10651, 'Die Wandernde Kuh'),
#  (10652, 'Gourmet Lanchonetes'),
#  (10653, 'Frankenversand'),
#  (10654, 'Berglunds snabbkp'),
#  (10655, 'Reggiani Caseifici'),
#  (10656, 'Great Lakes Food Market'),
#  (10657, 'Save-a-lot Markets'),
#  (10658, 'QUICK-Stop'),
#  (10659, 'Queen Cozinha'),
#  (10660, 'Hungry Coyote Import Store'),
#  (10661, 'Hungry Owl All-Night Grocers'),
#  (10662, 'Lonesome Pine Restaurant'),
#  (10663, 'Bon app-'),
#  (10664, 'Furia Bacalhau e Frutos do Mar'),
#  (10665, 'Lonesome Pine Restaurant'),
#  (10666, 'Richter Supermarkt'),
#  (10667, 'Ernst Handel'),
#  (10668, 'Die Wandernde Kuh'),
#  (10669, 'Simons bistro'),
#  (10670, 'Frankenversand'),
#  (10671, 'France restauration'),
#  (10672, 'Berglunds snabbkp'),
#  (10673, 'Wilman Kala'),
#  (10674, 'Island Trading'),
#  (10675, 'Frankenversand'),
#  (10676, 'Tortuga Restaurante'),
#  (10677, 'Antonio Moreno Taquera'),
#  (10678, 'Save-a-lot Markets'),
#  (10679, 'Blondel pre et fils'),
#  (10680, 'Old World Delicatessen'),
#  (10681, 'Great Lakes Food Market'),
#  (10682, 'Antonio Moreno Taquera'),
#  (10683, 'Du monde entier'),
#  (10684, 'Ottilies Kseladen'),
#  (10685, 'Gourmet Lanchonetes'),
#  (10686, 'Piccolo und mehr'),
#  (10687, 'Hungry Owl All-Night Grocers'),
#  (10688, 'Vaffeljernet'),
#  (10689, 'Berglunds snabbkp'),
#  (10690, 'Hanari Carnes'),
#  (10691, 'QUICK-Stop'),
#  (10692, 'Alfred-s Futterkiste'),
#  (10693, 'White Clover Markets'),
#  (10694, 'QUICK-Stop'),
#  (10695, 'Wilman Kala'),
#  (10696, 'White Clover Markets'),
#  (10697, 'LINO-Delicateses'),
#  (10698, 'Ernst Handel'),
#  (10699, 'Morgenstern Gesundkost'),
#  (10700, 'Save-a-lot Markets'),
#  (10701, 'Hungry Owl All-Night Grocers'),
#  (10702, 'Alfred-s Futterkiste'),
#  (10703, 'Folk och f HB'),
#  (10704, 'Queen Cozinha'),
#  (10705, 'HILARION-Abastos'),
#  (10706, 'Old World Delicatessen'),
#  (10707, 'Around the Horn'),
#  (10708, 'The Big Cheese'),
#  (10709, 'Gourmet Lanchonetes'),
#  (10710, 'Franchi S.p.A.'),
#  (10711, 'Save-a-lot Markets'),
#  (10712, 'Hungry Owl All-Night Grocers'),
#  (10713, 'Save-a-lot Markets'),
#  (10714, 'Save-a-lot Markets'),
#  (10715, 'Bon app-'),
#  (10716, 'Rancho grande'),
#  (10717, 'Frankenversand'),
#  (10718, 'Kniglich Essen'),
#  (10719, 'Let-s Stop N Shop'),
#  (10720, 'Que Delcia'),
#  (10721, 'QUICK-Stop'),
#  (10722, 'Save-a-lot Markets'),
#  (10723, 'White Clover Markets'),
#  (10724, 'Mre Paillarde'),
#  (10725, 'Familia Arquibaldo'),
#  (10726, 'Eastern Connection'),
#  (10727, 'Reggiani Caseifici'),
#  (10728, 'Queen Cozinha'),
#  (10729, 'LINO-Delicateses'),
#  (10730, 'Bon app-'),
#  (10731, 'Chop-suey Chinese'),
#  (10732, 'Bon app-'),
#  (10733, 'Berglunds snabbkp'),
#  (10734, 'Gourmet Lanchonetes'),
#  (10735, 'Let-s Stop N Shop'),
#  (10736, 'Hungry Owl All-Night Grocers'),
#  (10737, 'Vins et alcools Chevalier'),
#  (10738, 'Spcialits du monde'),
#  (10739, 'Vins et alcools Chevalier'),
#  (10740, 'White Clover Markets'),
#  (10741, 'Around the Horn'),
#  (10742, 'Bottom-Dollar Markets'),
#  (10743, 'Around the Horn'),
#  (10744, 'Vaffeljernet'),
#  (10745, 'QUICK-Stop'),
#  (10746, 'Chop-suey Chinese'),
#  (10747, 'Piccolo und mehr'),
#  (10748, 'Save-a-lot Markets'),
#  (10749, 'Island Trading'),
#  (10750, 'Wartian Herkku'),
#  (10751, 'Richter Supermarkt'),
#  (10752, 'North/South'),
#  (10753, 'Franchi S.p.A.'),
#  (10754, 'Magazzini Alimentari Riuniti'),
#  (10755, 'Bon app-'),
#  (10756, 'Split Rail Beer & Ale'),
#  (10757, 'Save-a-lot Markets'),
#  (10758, 'Richter Supermarkt'),
#  (10759, 'Ana Trujillo Emparedados y helados'),
#  (10760, 'Maison Dewey'),
#  (10761, 'Rattlesnake Canyon Grocery'),
#  (10762, 'Folk och f HB'),
#  (10763, 'Folies gourmandes'),
#  (10764, 'Ernst Handel'),
#  (10765, 'QUICK-Stop'),
#  (10766, 'Ottilies Kseladen'),
#  (10767, 'Suprmes dlices'),
#  (10768, 'Around the Horn'),
#  (10769, 'Vaffeljernet'),
#  (10770, 'Hanari Carnes'),
#  (10771, 'Ernst Handel'),
#  (10772, 'Lehmanns Marktstand'),
#  (10773, 'Ernst Handel'),
#  (10774, 'Folk och f HB'),
#  (10775, 'The Cracker Box'),
#  (10776, 'Ernst Handel'),
#  (10777, 'Gourmet Lanchonetes'),
#  (10778, 'Berglunds snabbkp'),
#  (10779, 'Morgenstern Gesundkost'),
#  (10780, 'LILA-Supermercado'),
#  (10781, 'Wartian Herkku'),
#  (10782, 'Cactus Comidas para llevar'),
#  (10783, 'Hanari Carnes'),
#  (10784, 'Magazzini Alimentari Riuniti'),
#  (10785, 'GROSELLA-Restaurante'),
#  (10786, 'Queen Cozinha'),
#  (10787, 'La maison d-Asie'),
#  (10788, 'QUICK-Stop'),
#  (10789, 'Folies gourmandes'),
#  (10790, 'Gourmet Lanchonetes'),
#  (10791, 'Frankenversand'),
#  (10792, 'Wolski Zajazd'),
#  (10793, 'Around the Horn'),
#  (10794, 'Que Delcia'),
#  (10795, 'Ernst Handel'),
#  (10796, 'HILARION-Abastos'),
#  (10797, 'Drachenblut Delikatessen'),
#  (10798, 'Island Trading'),
#  (10799, 'Kniglich Essen'),
#  (10800, 'Seven Seas Imports'),
#  (10801, 'Blido Comidas preparadas'),
#  (10802, 'Simons bistro'),
#  (10803, 'Wellington Importadora'),
#  (10804, 'Seven Seas Imports'),
#  (10805, 'The Big Cheese'),
#  (10806, 'Victuailles en stock'),
#  (10807, 'Franchi S.p.A.'),
#  (10808, 'Old World Delicatessen'),
#  (10809, 'Wellington Importadora'),
#  (10810, 'Laughing Bacchus Wine Cellars'),
#  (10811, 'LINO-Delicateses'),
#  (10812, 'Reggiani Caseifici'),
#  (10813, 'Ricardo Adocicados'),
#  (10814, 'Victuailles en stock'),
#  (10815, 'Save-a-lot Markets'),
#  (10816, 'Great Lakes Food Market'),
#  (10817, 'Kniglich Essen'),
#  (10818, 'Magazzini Alimentari Riuniti'),
#  (10819, 'Cactus Comidas para llevar'),
#  (10820, 'Rattlesnake Canyon Grocery'),
#  (10821, 'Split Rail Beer & Ale'),
#  (10822, 'Trail-s Head Gourmet Provisioners'),
#  (10823, 'LILA-Supermercado'),
#  (10824, 'Folk och f HB'),
#  (10825, 'Drachenblut Delikatessen'),
#  (10826, 'Blondel pre et fils'),
#  (10827, 'Bon app-'),
#  (10828, 'Rancho grande'),
#  (10829, 'Island Trading'),
#  (10830, 'Tradiao Hipermercados'),
#  (10831, 'Sant Gourmet'),
#  (10832, 'La maison d-Asie'),
#  (10833, 'Ottilies Kseladen'),
#  (10834, 'Tradiao Hipermercados'),
#  (10835, 'Alfred-s Futterkiste'),
#  (10836, 'Ernst Handel'),
#  (10837, 'Berglunds snabbkp'),
#  (10838, 'LINO-Delicateses'),
#  (10839, 'Tradiao Hipermercados'),
#  (10840, 'LINO-Delicateses'),
#  (10841, 'Suprmes dlices'),
#  (10842, 'Tortuga Restaurante'),
#  (10843, 'Victuailles en stock'),
#  (10844, 'Piccolo und mehr'),
#  (10845, 'QUICK-Stop'),
#  (10846, 'Suprmes dlices'),
#  (10847, 'Save-a-lot Markets'),
#  (10848, 'Consolidated Holdings'),
#  (10849, 'Kniglich Essen'),
#  (10850, 'Victuailles en stock'),
#  (10851, 'Ricardo Adocicados'),
#  (10852, 'Rattlesnake Canyon Grocery'),
#  (10853, 'Blauer See Delikatessen'),
#  (10854, 'Ernst Handel'),
#  (10855, 'Old World Delicatessen'),
#  (10856, 'Antonio Moreno Taquera'),
#  (10857, 'Berglunds snabbkp'),
#  (10858, 'La corne d-abondance'),
#  (10859, 'Frankenversand'),
#  (10860, 'France restauration'),
#  (10861, 'White Clover Markets'),
#  (10862, 'Lehmanns Marktstand'),
#  (10863, 'HILARION-Abastos'),
#  (10864, 'Around the Horn'),
#  (10865, 'QUICK-Stop'),
#  (10866, 'Berglunds snabbkp'),
#  (10867, 'Lonesome Pine Restaurant'),
#  (10868, 'Queen Cozinha'),
#  (10869, 'Seven Seas Imports'),
#  (10870, 'Wolski Zajazd'),
#  (10871, 'Bon app-'),
#  (10872, 'Godos Cocina Tpica'),
#  (10873, 'Wilman Kala'),
#  (10874, 'Godos Cocina Tpica'),
#  (10875, 'Berglunds snabbkp'),
#  (10876, 'Bon app-'),
#  (10877, 'Ricardo Adocicados'),
#  (10878, 'QUICK-Stop'),
#  (10879, 'Wilman Kala'),
#  (10880, 'Folk och f HB'),
#  (10881, 'Cactus Comidas para llevar'),
#  (10882, 'Save-a-lot Markets'),
#  (10883, 'Lonesome Pine Restaurant'),
#  (10884, 'Let-s Stop N Shop'),
#  (10885, 'Suprmes dlices'),
#  (10886, 'Hanari Carnes'),
#  (10887, 'Galera del gastronmo'),
#  (10888, 'Godos Cocina Tpica'),
#  (10889, 'Rattlesnake Canyon Grocery'),
#  (10890, 'Du monde entier'),
#  (10891, 'Lehmanns Marktstand'),
#  (10892, 'Maison Dewey'),
#  (10893, 'Kniglich Essen'),
#  (10894, 'Save-a-lot Markets'),
#  (10895, 'Ernst Handel'),
#  (10896, 'Maison Dewey'),
#  (10897, 'Hungry Owl All-Night Grocers'),
#  (10898, 'Ocano Atlntico Ltda.'),
#  (10899, 'LILA-Supermercado'),
#  (10900, 'Wellington Importadora'),
#  (10901, 'HILARION-Abastos'),
#  (10902, 'Folk och f HB'),
#  (10903, 'Hanari Carnes'),
#  (10904, 'White Clover Markets'),
#  (10905, 'Wellington Importadora'),
#  (10906, 'Wolski Zajazd'),
#  (10907, 'Spcialits du monde'),
#  (10908, 'Reggiani Caseifici'),
#  (10909, 'Sant Gourmet'),
#  (10910, 'Wilman Kala'),
#  (10911, 'Godos Cocina Tpica'),
#  (10912, 'Hungry Owl All-Night Grocers'),
#  (10913, 'Queen Cozinha'),
#  (10914, 'Queen Cozinha'),
#  (10915, 'Tortuga Restaurante'),
#  (10916, 'Rancho grande'),
#  (10917, 'Romero y tomillo'),
#  (10918, 'Bottom-Dollar Markets'),
#  (10919, 'LINO-Delicateses'),
#  (10920, 'Around the Horn'),
#  (10921, 'Vaffeljernet'),
#  (10922, 'Hanari Carnes'),
#  (10923, 'La maison d-Asie'),
#  (10924, 'Berglunds snabbkp'),
#  (10925, 'Hanari Carnes'),
#  (10926, 'Ana Trujillo Emparedados y helados'),
#  (10927, 'La corne d-abondance'),
#  (10928, 'Galera del gastronmo'),
#  (10929, 'Frankenversand'),
#  (10930, 'Suprmes dlices'),
#  (10931, 'Richter Supermarkt'),
#  (10932, 'Bon app-'),
#  (10933, 'Island Trading'),
#  (10934, 'Lehmanns Marktstand'),
#  (10935, 'Wellington Importadora'),
#  (10936, 'Great Lakes Food Market'),
#  (10937, 'Cactus Comidas para llevar'),
#  (10938, 'QUICK-Stop'),
#  (10939, 'Magazzini Alimentari Riuniti'),
#  (10940, 'Bon app-'),
#  (10941, 'Save-a-lot Markets'),
#  (10942, 'Reggiani Caseifici'),
#  (10943, 'B-s Beverages'),
#  (10944, 'Bottom-Dollar Markets'),
#  (10945, 'Morgenstern Gesundkost'),
#  (10946, 'Vaffeljernet'),
#  (10947, 'B-s Beverages'),
#  (10948, 'Godos Cocina Tpica'),
#  (10949, 'Bottom-Dollar Markets'),
#  (10950, 'Magazzini Alimentari Riuniti'),
#  (10951, 'Richter Supermarkt'),
#  (10952, 'Alfred-s Futterkiste'),
#  (10953, 'Around the Horn'),
#  (10954, 'LINO-Delicateses'),
#  (10955, 'Folk och f HB'),
#  (10956, 'Blauer See Delikatessen'),
#  (10957, 'HILARION-Abastos'),
#  (10958, 'Ocano Atlntico Ltda.'),
#  (10959, 'Gourmet Lanchonetes'),
#  (10960, 'HILARION-Abastos'),
#  (10961, 'Queen Cozinha'),
#  (10962, 'QUICK-Stop'),
#  (10963, 'Furia Bacalhau e Frutos do Mar'),
#  (10964, 'Spcialits du monde'),
#  (10965, 'Old World Delicatessen'),
#  (10966, 'Chop-suey Chinese'),
#  (10967, 'Toms Spezialitten'),
#  (10968, 'Ernst Handel'),
#  (10969, 'Comrcio Mineiro'),
#  (10970, 'Blido Comidas preparadas'),
#  (10971, 'France restauration'),
#  (10972, 'La corne d-abondance'),
#  (10973, 'La corne d-abondance'),
#  (10974, 'Split Rail Beer & Ale'),
#  (10975, 'Bottom-Dollar Markets'),
#  (10976, 'HILARION-Abastos'),
#  (10977, 'Folk och f HB'),
#  (10978, 'Maison Dewey'),
#  (10979, 'Ernst Handel'),
#  (10980, 'Folk och f HB'),
#  (10981, 'Hanari Carnes'),
#  (10982, 'Bottom-Dollar Markets'),
#  (10983, 'Save-a-lot Markets'),
#  (10984, 'Save-a-lot Markets'),
#  (10985, 'Hungry Owl All-Night Grocers'),
#  (10986, 'Ocano Atlntico Ltda.'),
#  (10987, 'Eastern Connection'),
#  (10988, 'Rattlesnake Canyon Grocery'),
#  (10989, 'Que Delcia'),
#  (10990, 'Ernst Handel'),
#  (10991, 'QUICK-Stop'),
#  (10992, 'The Big Cheese'),
#  (10993, 'Folk och f HB'),
#  (10994, 'Vaffeljernet'),
#  (10995, 'Pericles Comidas clsicas'),
#  (10996, 'QUICK-Stop'),
#  (10997, 'LILA-Supermercado'),
#  (10998, 'Wolski Zajazd'),
#  (10999, 'Ottilies Kseladen'),
#  (11000, 'Rattlesnake Canyon Grocery'),
#  (11001, 'Folk och f HB'),
#  (11002, 'Save-a-lot Markets'),
#  (11003, 'The Cracker Box'),
#  (11004, 'Maison Dewey'),
#  (11005, 'Wilman Kala'),
#  (11006, 'Great Lakes Food Market'),
#  (11007, 'Princesa Isabel Vinhos'),
#  (11008, 'Ernst Handel'),
#  (11009, 'Godos Cocina Tpica'),
#  (11010, 'Reggiani Caseifici'),
#  (11011, 'Alfred-s Futterkiste'),
#  (11012, 'Frankenversand'),
#  (11013, 'Romero y tomillo'),
#  (11014, 'LINO-Delicateses'),
#  (11015, 'Sant Gourmet'),
#  (11016, 'Around the Horn'),
#  (11017, 'Ernst Handel'),
#  (11018, 'Lonesome Pine Restaurant'),
#  (11019, 'Rancho grande'),
#  (11020, 'Ottilies Kseladen'),
#  (11021, 'QUICK-Stop'),
#  (11022, 'Hanari Carnes'),
#  (11023, 'B-s Beverages'),
#  (11024, 'Eastern Connection'),
#  (11025, 'Wartian Herkku'),
#  (11026, 'Franchi S.p.A.'),
#  (11027, 'Bottom-Dollar Markets'),
#  (11028, 'Kniglich Essen'),
#  (11029, 'Chop-suey Chinese'),
#  (11030, 'Save-a-lot Markets'),
#  (11031, 'Save-a-lot Markets'),
#  (11032, 'White Clover Markets'),
#  (11033, 'Richter Supermarkt'),
#  (11034, 'Old World Delicatessen'),
#  (11035, 'Suprmes dlices'),
#  (11036, 'Drachenblut Delikatessen'),
#  (11037, 'Godos Cocina Tpica'),
#  (11038, 'Suprmes dlices'),
#  (11039, 'LINO-Delicateses'),
#  (11040, 'Great Lakes Food Market'),
#  (11041, 'Chop-suey Chinese'),
#  (11042, 'Comrcio Mineiro'),
#  (11043, 'Spcialits du monde'),
#  (11044, 'Wolski Zajazd'),
#  (11045, 'Bottom-Dollar Markets'),
#  (11046, 'Die Wandernde Kuh'),
#  (11047, 'Eastern Connection'),
#  (11048, 'Bottom-Dollar Markets'),
#  (11049, 'Gourmet Lanchonetes'),
#  (11050, 'Folk och f HB'),
#  (11051, 'La maison d-Asie'),
#  (11052, 'Hanari Carnes'),
#  (11053, 'Piccolo und mehr'),
#  (11054, 'Cactus Comidas para llevar'),
#  (11055, 'HILARION-Abastos'),
#  (11056, 'Eastern Connection'),
#  (11057, 'North/South'),
#  (11058, 'Blauer See Delikatessen'),
#  (11059, 'Ricardo Adocicados'),
#  (11060, 'Franchi S.p.A.'),
#  (11061, 'Great Lakes Food Market'),
#  (11062, 'Reggiani Caseifici'),
#  (11063, 'Hungry Owl All-Night Grocers'),
#  (11064, 'Save-a-lot Markets'),
#  (11065, 'LILA-Supermercado'),
#  (11066, 'White Clover Markets'),
#  (11067, 'Drachenblut Delikatessen'),
#  (11068, 'Queen Cozinha'),
#  (11069, 'Tortuga Restaurante'),
#  (11070, 'Lehmanns Marktstand'),
#  (11071, 'LILA-Supermercado'),
#  (11072, 'Ernst Handel'),
#  (11073, 'Pericles Comidas clsicas'),
#  (11074, 'Simons bistro'),
#  (11075, 'Richter Supermarkt'),
#  (11076, 'Bon app-'),
#  (11077, 'Rattlesnake Canyon Grocery')]

# %% [markdown]
# ### 3. Replace string
#
# The `Customers` table contains null values in the `ContactTitle` column. Write a SQL command to replace these null values with the string 'N/A'.

# %%
# %%sql
#
# select
# 	CustomerId,
#     IFNULL(ContactTitle,'N/A')
# from
# 	Customers;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('ALFKI', 'Sales Representative'),
#  ('ANATR', 'Owner'),
#  ('ANTON', 'Owner'),
#  ('AROUT', 'Sales Representative'),
#  ('BERGS', 'Order Administrator'),
#  ('BLAUS', 'Sales Representative'),
#  ('BLONP', 'Marketing Manager'),
#  ('BOLID', 'Owner'),
#  ('BONAP', 'Owner'),
#  ('BOTTM', 'Accounting Manager'),
#  ('BSBEV', 'Sales Representative'),
#  ('CACTU', 'Sales Agent'),
#  ('CENTC', 'Marketing Manager'),
#  ('CHOPS', 'Owner'),
#  ('COMMI', 'Sales Associate'),
#  ('CONSH', 'Sales Representative'),
#  ('DRACD', 'Order Administrator'),
#  ('DUMON', 'Owner'),
#  ('EASTC', 'Sales Agent'),
#  ('ERNSH', 'Sales Manager'),
#  ('FAMIA', 'Marketing Assistant'),
#  ('FISSA', 'Accounting Manager'),
#  ('FOLIG', 'Assistant Sales Agent'),
#  ('FOLKO', 'Owner'),
#  ('FRANK', 'Marketing Manager'),
#  ('FRANR', 'Marketing Manager'),
#  ('FRANS', 'Sales Representative'),
#  ('FURIB', 'Sales Manager'),
#  ('GALED', 'Marketing Manager'),
#  ('GODOS', 'Sales Manager'),
#  ('GOURL', 'Sales Associate'),
#  ('GREAL', 'Marketing Manager'),
#  ('GROSR', 'Owner'),
#  ('HANAR', 'Accounting Manager'),
#  ('HILAA', 'Sales Representative'),
#  ('HUNGC', 'Sales Representative'),
#  ('HUNGO', 'Sales Associate'),
#  ('ISLAT', 'Marketing Manager'),
#  ('KOENE', 'Sales Associate'),
#  ('LACOR', 'Sales Representative'),
#  ('LAMAI', 'Sales Manager'),
#  ('LAUGB', 'Marketing Assistant'),
#  ('LAZYK', 'Marketing Manager'),
#  ('LEHMS', 'Sales Representative'),
#  ('LETSS', 'Owner'),
#  ('LILAS', 'Accounting Manager'),
#  ('LINOD', 'Owner'),
#  ('LONEP', 'Sales Manager'),
#  ('MAGAA', 'Marketing Manager'),
#  ('MAISD', 'Sales Agent'),
#  ('MEREP', 'Marketing Assistant'),
#  ('MORGK', 'Marketing Assistant'),
#  ('NORTS', 'Sales Associate'),
#  ('OCEAN', 'Sales Agent'),
#  ('OLDWO', 'Sales Representative'),
#  ('OTTIK', 'Owner'),
#  ('PARIS', 'Owner'),
#  ('PERIC', 'Sales Representative'),
#  ('PICCO', 'Sales Manager'),
#  ('PRINI', 'Sales Representative'),
#  ('QUEDE', 'Accounting Manager'),
#  ('QUEEN', 'Marketing Assistant'),
#  ('QUICK', 'Accounting Manager'),
#  ('RANCH', 'Sales Representative'),
#  ('RATTC', 'Assistant Sales Representative'),
#  ('REGGC', 'Sales Associate'),
#  ('RICAR', 'Assistant Sales Agent'),
#  ('RICSU', 'Sales Manager'),
#  ('ROMEY', 'Accounting Manager'),
#  ('SANTG', 'Owner'),
#  ('SAVEA', 'Sales Representative'),
#  ('SEVES', 'Sales Manager'),
#  ('SIMOB', 'Owner'),
#  ('SPECD', 'Marketing Manager'),
#  ('SPLIR', 'Sales Manager'),
#  ('SUPRD', 'Accounting Manager'),
#  ('THEBI', 'Marketing Manager'),
#  ('THECR', 'Marketing Assistant'),
#  ('TOMSP', 'Marketing Manager'),
#  ('TORTU', 'Owner'),
#  ('TRADH', 'Sales Representative'),
#  ('TRAIH', 'Sales Associate'),
#  ('VAFFE', 'Sales Manager'),
#  ('Val2 ', 'IT'),
#  ('VALON', 'IT'),
#  ('VICTE', 'Sales Agent'),
#  ('VINET', 'Accounting Manager'),
#  ('WANDK', 'Sales Representative'),
#  ('WARTH', 'Accounting Manager'),
#  ('WELLI', 'Sales Manager'),
#  ('WHITC', 'Owner'),
#  ('WILMK', 'Owner/Marketing Assistant'),
#  ('WOLZA', 'Owner')]

# %% [markdown]
# ### 4. Extract characters
#
# Write a SQL command to extract the first three characters from the `City` column in the `Customers` table.

# %%
# %%sql
#
# select
# 	CustomerId,
#     City,
#     SubString(City,1,3)
# from
# 	Customers;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('ALFKI', 'Berlin', 'Ber'),
#  ('ANATR', 'Mxico D.F.', 'Mxi'),
#  ('ANTON', 'Mxico D.F.', 'Mxi'),
#  ('AROUT', 'London', 'Lon'),
#  ('BERGS', 'Lule', 'Lul'),
#  ('BLAUS', 'Mannheim', 'Man'),
#  ('BLONP', 'Strasbourg', 'Str'),
#  ('BOLID', 'Madrid', 'Mad'),
#  ('BONAP', 'Marseille', 'Mar'),
#  ('BOTTM', 'Tsawassen', 'Tsa'),
#  ('BSBEV', 'London', 'Lon'),
#  ('CACTU', 'Buenos Aires', 'Bue'),
#  ('CENTC', 'Mxico D.F.', 'Mxi'),
#  ('CHOPS', 'Bern', 'Ber'),
#  ('COMMI', 'Sao Paulo', 'Sao'),
#  ('CONSH', 'London', 'Lon'),
#  ('DRACD', 'Aachen', 'Aac'),
#  ('DUMON', 'Nantes', 'Nan'),
#  ('EASTC', 'London', 'Lon'),
#  ('ERNSH', 'Graz', 'Gra'),
#  ('FAMIA', 'Sao Paulo', 'Sao'),
#  ('FISSA', 'Madrid', 'Mad'),
#  ('FOLIG', 'Lille', 'Lil'),
#  ('FOLKO', 'Brcke', 'Brc'),
#  ('FRANK', 'Mnchen', 'Mnc'),
#  ('FRANR', 'Nantes', 'Nan'),
#  ('FRANS', 'Torino', 'Tor'),
#  ('FURIB', 'Lisboa', 'Lis'),
#  ('GALED', 'Barcelona', 'Bar'),
#  ('GODOS', 'Sevilla', 'Sev'),
#  ('GOURL', 'Campinas', 'Cam'),
#  ('GREAL', 'Eugene', 'Eug'),
#  ('GROSR', 'Caracas', 'Car'),
#  ('HANAR', 'Rio de Janeiro', 'Rio'),
#  ('HILAA', 'San Cristbal', 'San'),
#  ('HUNGC', 'Elgin', 'Elg'),
#  ('HUNGO', 'Cork', 'Cor'),
#  ('ISLAT', 'Cowes', 'Cow'),
#  ('KOENE', 'Brandenburg', 'Bra'),
#  ('LACOR', 'Versailles', 'Ver'),
#  ('LAMAI', 'Toulouse', 'Tou'),
#  ('LAUGB', 'Vancouver', 'Van'),
#  ('LAZYK', 'Walla Walla', 'Wal'),
#  ('LEHMS', 'Frankfurt a.M.', 'Fra'),
#  ('LETSS', 'San Francisco', 'San'),
#  ('LILAS', 'Barquisimeto', 'Bar'),
#  ('LINOD', 'I. de Margarita', 'I. '),
#  ('LONEP', 'Portland', 'Por'),
#  ('MAGAA', 'Bergamo', 'Ber'),
#  ('MAISD', 'Bruxelles', 'Bru'),
#  ('MEREP', 'Montral', 'Mon'),
#  ('MORGK', 'Leipzig', 'Lei'),
#  ('NORTS', 'London', 'Lon'),
#  ('OCEAN', 'Buenos Aires', 'Bue'),
#  ('OLDWO', 'Anchorage', 'Anc'),
#  ('OTTIK', 'Kln', 'Kln'),
#  ('PARIS', 'Paris', 'Par'),
#  ('PERIC', 'Mxico D.F.', 'Mxi'),
#  ('PICCO', 'Salzburg', 'Sal'),
#  ('PRINI', 'Lisboa', 'Lis'),
#  ('QUEDE', 'Rio de Janeiro', 'Rio'),
#  ('QUEEN', 'Sao Paulo', 'Sao'),
#  ('QUICK', 'Cunewalde', 'Cun'),
#  ('RANCH', 'Buenos Aires', 'Bue'),
#  ('RATTC', 'Albuquerque', 'Alb'),
#  ('REGGC', 'Reggio Emilia', 'Reg'),
#  ('RICAR', 'Rio de Janeiro', 'Rio'),
#  ('RICSU', 'Genve', 'Gen'),
#  ('ROMEY', 'Madrid', 'Mad'),
#  ('SANTG', 'Stavern', 'Sta'),
#  ('SAVEA', 'Boise', 'Boi'),
#  ('SEVES', 'London', 'Lon'),
#  ('SIMOB', 'Kobenhavn', 'Kob'),
#  ('SPECD', 'Paris', 'Par'),
#  ('SPLIR', 'Lander', 'Lan'),
#  ('SUPRD', 'Charleroi', 'Cha'),
#  ('THEBI', 'Portland', 'Por'),
#  ('THECR', 'Butte', 'But'),
#  ('TOMSP', 'Mnster', 'Mns'),
#  ('TORTU', 'Mxico D.F.', 'Mxi'),
#  ('TRADH', 'Sao Paulo', 'Sao'),
#  ('TRAIH', 'Kirkland', 'Kir'),
#  ('VAFFE', 'rhus', 'rhu'),
#  ('Val2 ', None, None),
#  ('VALON', None, None),
#  ('VICTE', 'Lyon', 'Lyo'),
#  ('VINET', 'Reims', 'Rei'),
#  ('WANDK', 'Stuttgart', 'Stu'),
#  ('WARTH', 'Oulu', 'Oul'),
#  ('WELLI', 'Resende', 'Res'),
#  ('WHITC', 'Seattle', 'Sea'),
#  ('WILMK', 'Helsinki', 'Hel'),
#  ('WOLZA', 'Warszawa', 'War')]

# %% [markdown]
# ### 5. String concatenation
#
# Write a SQL query to concatenate the `FirstName` and `LastName` of employees in the `Employees` table into a new column `FullName`.

# %%
# %%sql
#
# select
# 	FirstName,
#     LastName,
#     CONCAT(
#         FirstName,
#         ' ',
#         LastName
#     ) AS FullName
# from
# 	employees;
# Out:
#  * sqlite:///Northwind.db
# (sqlite3.OperationalError) no such function: CONCAT
# [SQL: select
# 	FirstName,
#     LastName,
#     CONCAT(
#         FirstName,
#         ' ',
#         LastName
#     ) AS FullName
# from
# 	employees;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### Challenge question
#
# You are working in the marketing department of your company and you have been given the task of conducting an email marketing campaign targeting all customers based in France.

# %% [markdown]
# You have a `Customers` table which includes an `Email` column. However, the data isn't perfect. Some email addresses might be duplicated, others might be `NULL`, and some might have unnecessary white spaces at the start or end of the address.
#
# Your task is to clean up the data and compile a list of unique email addresses to use for the marketing campaign. Here are the requirements:

# %% [markdown]
# 1. Exclude any `NULL` email addresses from your list. We can't send emails to addresses we don't have.
# 2. Make sure there are no duplicates in your list. We don't want to annoy our customers by sending them the same email multiple times.
# 3. Remove any unnecessary white spaces from the start or end of the email addresses. This will help avoid any errors when sending the emails.

# %% [markdown]
# Remember, the success of our campaign depends on the quality of this list!
#
# Your output should look something like this, though the exact email addresses will depend on the data in your `Customers` table:

# %% [raw]
# customer1@example.com
# customer2@example.com
# customer3@example.com

# %%
# Add your code here

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Convert data type
#
# The `CAST` function is used to convert one data type to another. In this query, it is used to convert the `Salary` column from an integer to a string.

# %%
# %%sql
#
# SELECT
#     CAST(Salary AS CHAR) AS SalaryString
# FROM
#     Employees;

# %% [markdown]
# ### 2. Trim strings
#
# The `TRIM` function is used to remove leading and trailing spaces from a string. This query uses `TRIM` to remove spaces from the `ShipName` entries.

# %%
# %%sql
#
# SELECT
#     TRIM(ShipName) AS TrimmedShipName
# FROM
#     Orders;

# %% [markdown]
# ### 3. Replace string
#
# The `COALESCE` function returns the first non-null value in a list. In this case, it's used to replace `NULL` values in the `ContactTitle` column with `'N/A'`.

# %%
# %%sql
#
# UPDATE
#     Customers
# SET
#     ContactTitle = COALESCE(ContactTitle, 'N/A');
# Out:
#  * sqlite:///Northwind.db
# 93 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "\nUPDATE \n    Customers \nSET \n    ContactTitle = COALESCE(ContactTitle, 'N/A');\n")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2493, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2491 with self.builtin_trap:
#    2492     args = (magic_arg_s, cell)
# -> 2493     result = fn(*args, **kwargs)
#    2495 # The code below prevents the output from being displayed
#    2496 # when using magics with decorator @output_can_be_silenced
#    2497 # when the last Python token in the expression is a ';'.
#    2498 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sql\magic.py:95, in SqlMagic.execute(self, line, cell, local_ns)
#      92     return self._persist_dataframe(parsed['sql'], conn, user_ns)
#      94 try:
# ---> 95     result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      97     if result is not None and not isinstance(result, str) and self.column_local_vars:
#      98         #Instead of returning values, set variables directly in the
#      99         #users namespace. Variable names given by column names
#     101         if self.autopandas:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sql\run.py:344, in run(conn, sql, config, user_namespace)
#     342     if result and config.feedback:
#     343         print(interpret_rowcount(result.rowcount))
# --> 344 resultset = ResultSet(result, statement, config)
#     345 if config.autopandas:
#     346     return resultset.DataFrame()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sql\run.py:107, in ResultSet.__init__(self, sqlaproxy, sql, config)
#     106 def __init__(self, sqlaproxy, sql, config):
# --> 107     self.keys = sqlaproxy.keys()
#     108     self.sql = sql
#     109     self.config = config
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\result.py:700, in _WithKeys.keys(self)
#     683 def keys(self):
#     684     """Return an iterable view which yields the string keys that would
#     685     be represented by each :class:`.Row`.
#     686
#    (...)
#     698
#     699     """
# --> 700     return self._metadata.keys
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\cursor.py:1201, in _NoResultMetaData.keys(self)
#    1199 @property
#    1200 def keys(self):
# -> 1201     self._we_dont_return_rows()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\cursor.py:1178, in _NoResultMetaData._we_dont_return_rows(self, err)
#    1177 def _we_dont_return_rows(self, err=None):
# -> 1178     util.raise_(
#    1179         exc.ResourceClosedError(
#    1180             "This result object does not return rows. "
#    1181             "It has been closed automatically."
#    1182         ),
#    1183         replace_context=err,
#    1184     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# ### 4. Extract characters
#
# The `LEFT` function is used to extract a specified number of characters from a string, starting from the left. This query extracts the first three characters from the `City` column.

# %%
# %%sql
#
# SELECT
#     LEFT(City, 3) AS CitySubstring
# FROM
#     Customers;

# %% [markdown]
# ### 5. String concatenation
#
# The `CONCAT` function is used to combine two or more strings into one. This query concatenates the `FirstName` and `LastName` columns with a space in between.

# %%
# %%sql
#
# SELECT
#     CONCAT(FirstName, ' ', LastName) AS FullName
# FROM
#     Employees;
# Out:
#  * sqlite:///Northwind.db
# (sqlite3.OperationalError) no such function: CONCAT
# [SQL: SELECT
#     CONCAT(FirstName, ' ', LastName) AS FullName
# FROM
#     Employees;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### Challenge question
#
# The SQL statement is reading data from the Customers table (`FROM` Customers).
#
# The `WHERE` clause filters out the customers who are based in France `(Country = 'France')` and whose email address is not `NULL (AND Email IS NOT NULL)`.
#
# The `SELECT DISTINCT TRIM(Email)` part of the statement is where the magic happens. `TRIM(Email)` removes any white spaces from the start and end of the email addresses. And `DISTINCT` ensures that each email address in your results is unique.
#
# Thus, this query will return a list of unique, cleaned-up email addresses for all customers in France, ready for you to use in your marketing campaign.

# %%
# %%sql
#
# SELECT
#     DISTINCT TRIM(Email)
# FROM
#     Customers
# WHERE
#     Country = 'France'
#     AND Email IS NOT NULL;
# Out:
#  * sqlite:///Northwind.db
# (sqlite3.OperationalError) no such column: Email
# [SQL: SELECT
#     DISTINCT TRIM(Email)
# FROM
#     Customers
# WHERE
#     Country = 'France'
#     AND Email IS NOT NULL;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
